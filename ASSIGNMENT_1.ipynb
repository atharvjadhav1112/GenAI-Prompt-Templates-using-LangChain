# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\atharv jadhav\anaconda3\lib\site-packages (1.2.10)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langchain) (1.2.14)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langchain) (1.0.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.4)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.7)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.24.0)
# Requirement already satisfied: anyio in c:\users\atharv jadhav\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (4.10.0)
# Requirement already satisfied: certifi in c:\users\atharv jadhav\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\atharv jadhav\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\atharv jadhav\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\atharv jadhav\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.3.1)

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# ## Task 1: Replace Hardcoded Prompts

# %%
# Define PromptTemplate
explain_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

# Function using template
def explain_topic(topic):
    return explain_template.format(topic=topic)

# Test
print(explain_topic("Artificial Intelligence"))
# Out:
# Explain Artificial Intelligence in simple terms for beginners

# %% [markdown]
# ## Task 2: Multi-Input Prompt System

# %%
multi_input_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

# Test Cases
print(multi_input_template.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_input_template.format(topic="Python", audience="kids", tone="fun"))
print(multi_input_template.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %% [markdown]
# ## Task 3: Prompt Variations Engine

# %%
# Teaching Template
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

# Interview Template
interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

# Storytelling Template
story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

# Test
topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story

# %% [markdown]
#  ## Task 4: ChatPromptTemplate System

# %%
def build_chat_prompt(role, topic):
    
    system_roles = {
        "teacher": "You are a helpful teacher explaining concepts clearly.",
        "interviewer": "You are an interviewer asking insightful questions.",
        "motivator": "You are a motivational speaker inspiring learning."
    }
    
    system_template = system_roles.get(role, "You are a helpful assistant.")
    
    chat_template = ChatPromptTemplate.from_messages([
        ("system", system_template),
        ("user", "Explain {topic}")
    ])
    
    return chat_template.format_messages(topic=topic)

# Test
messages = build_chat_prompt("teacher", "Neural Networks")
print(messages)
# Out:
# [SystemMessage(content='You are a helpful teacher explaining concepts clearly.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain Neural Networks', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ## Task 5: Input Validation Layer

# %%
def validate_inputs(audience, tone):
    
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]
    
    if audience not in valid_audience:
        print("Invalid audience. Setting default to 'beginner'")
        audience = "beginner"
        
    if tone not in valid_tone:
        print("Invalid tone. Setting default to 'formal'")
        tone = "formal"
        
    return audience, tone

# Test
print(validate_inputs("kids", "funny"))
# Out:
# Invalid audience. Setting default to 'beginner'
# Invalid tone. Setting default to 'formal'
# ('beginner', 'formal')

# %% [markdown]
#  ## Task 6: Prompt Generator App

# %%
# Style Templates
style_templates = {
    "teaching": PromptTemplate(
        input_variables=["topic", "audience", "tone"],
        template="Explain {topic} for {audience} in a {tone} teaching style"
    ),
    
    "interview": PromptTemplate(
        input_variables=["topic", "audience", "tone"],
        template="Generate interview questions on {topic} for {audience} in a {tone} tone"
    ),
    
    "storytelling": PromptTemplate(
        input_variables=["topic", "audience", "tone"],
        template="Explain {topic} for {audience} in a {tone} storytelling style"
    )
}

def generate_prompt(topic, audience, tone, style):
    
    audience, tone = validate_inputs(audience, tone)
    
    template = style_templates.get(style)
    
    if template is None:
        return "Invalid style selected"
    
    return template.format(topic=topic, audience=audience, tone=tone)

# Test
print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# Explain Neural Networks for beginner in a fun storytelling style

# %% [markdown]
# ## Task 7: Template Reusability Test

# %%
reusable_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

topics = ["AI", "Python", "Blockchain", "Cyber Security", "Data Science"]

for t in topics:
    print(reusable_template.format(topic=t))
# Out:
# Explain AI in simple terms
# Explain Python in simple terms
# Explain Blockchain in simple terms
# Explain Cyber Security in simple terms
# Explain Data Science in simple terms

# %% [markdown]
# ## Pipeline Flow Demonstration

# %%
def full_pipeline(topic, audience, tone, style):
    
    # Step 1: Validate
    audience, tone = validate_inputs(audience, tone)
    
    # Step 2: Generate Prompt
    prompt = generate_prompt(topic, audience, tone, style)
    
    return prompt

# Test Pipeline
print(full_pipeline("Deep Learning", "expert", "formal", "teaching"))
# Out:
# Explain Deep Learning for expert in a formal teaching style
